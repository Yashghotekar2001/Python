# %%
d1={}
d1
# Out:
# {}

# %%
d2=dict()
d2
# Out:
# {}

# %%
d3={1:'Ram',2:'Sham',3:'Raj'}
d3[1]
# Out:
# 'Ram'

# %%
d3.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
d3.values()
# Out:
# dict_values(['Ram', 'Sham', 'Raj'])

# %%
d3.items()
# Out:
# dict_items([(1, 'Ram'), (2, 'Sham'), (3, 'Raj')])

# %%
d3[2]='Sachin'
d3
# Out:
# {1: 'Ram', 2: 'Sachin', 3: 'Raj'}

# %%
d3[5]='Ram'
d3
# Out:
# {1: 'Ram', 2: 'Sachin', 3: 'Raj', 5: 'Ram'}

# %%
mydict=dict()
mydict
# Out:
# {}

# %%
(type(mydict))
# Out:
# dict

# %%
mydict={1:'one',2:'two',3:'three'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict=dict({1:'one',2:'two',3:'three'})
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
mydict.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'three')])

# %%
v=[0,1,2,3,[8,{5:[67,89,90,{'area':'kudlu','city':'banglore'}]}]]

# %%
v[4][1][5][3]['city']
# Out:
# 'banglore'

# %%
#add,remove&changes

# %%
mydict1={'Name':'Data','ID':12345,'DOB':1991,'Address':'Hilsinki'}
mydict1
# Out:
# {'Name': 'Data', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1.update({'xyz':'value111'})
mydict1
# Out:
# {'Name': 'Data',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Hilsinki',
#  'xyz': 'value111'}

# %%
mydict1['DOB']=1992
mydict1
# Out:
# {'Name': 'Data',
#  'ID': 12345,
#  'DOB': 1992,
#  'Address': 'Hilsinki',
#  'xyz': 'value111'}

# %%
mydict1['ABC']=1
mydict1
# Out:
# {'Name': 'Data',
#  'ID': 12345,
#  'DOB': 1992,
#  'Address': 'Hilsinki',
#  'xyz': 'value111',
#  'ABC': 1}

# %%
mydict1['Job']='Analyst'
mydict1
# Out:
# {'Name': 'Data',
#  'ID': 12345,
#  'DOB': 1992,
#  'Address': 'Hilsinki',
#  'xyz': 'value111',
#  'ABC': 1,
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job')
mydict1
# Out:
# {'Name': 'Data',
#  'ID': 12345,
#  'DOB': 1992,
#  'Address': 'Hilsinki',
#  'xyz': 'value111',
#  'ABC': 1}

# %%
mydict1.popitem()
mydict1
# Out:
# {'Name': 'Data',
#  'ID': 12345,
#  'DOB': 1992,
#  'Address': 'Hilsinki',
#  'xyz': 'value111'}

# %%
del[mydict1['ID']]
mydict1
# Out:
# {'Name': 'Data', 'DOB': 1992, 'Address': 'Hilsinki', 'xyz': 'value111'}

# %%
mydict1.clear()
mydict1
# Out:
# {}
